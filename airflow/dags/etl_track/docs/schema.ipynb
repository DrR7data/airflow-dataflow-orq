# %% [markdown]
# ### Silver

# %% [markdown]
# ![what-is-an-agent.png](/workspaces/airflow-dataflow-orq/airflow/dags/etl_track/docs/bronze.png "bronze.png")

# %% [markdown]
# ### Bronze

# %% [markdown]
# ![what-is-an-agent.png](/workspaces/airflow-dataflow-orq/airflow/dags/etl_track/docs/schema_silver.png "schema_silver.png")

# %% [markdown]
# ### Gold

# %% [markdown]
# ![what-is-an-agent.png](/workspaces/airflow-dataflow-orq/airflow/dags/etl_track/docs/gold.png "gold.png")
